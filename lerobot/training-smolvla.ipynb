# %% [markdown]
# # 🤗 x 🦾: Training SmolVLA with LeRobot Notebook
#
# Welcome to the **LeRobot SmolVLA training notebook**! This notebook provides a ready-to-run setup for training imitation learning policies using the [🤗 LeRobot](https://github.com/huggingface/lerobot) library.
#
# In this example, we train an `SmolVLA` policy using a dataset hosted on the [Hugging Face Hub](https://huggingface.co/), and optionally track training metrics with [Weights & Biases (wandb)](https://wandb.ai/).
#
# ## ⚙️ Requirements
# - A Hugging Face dataset repo ID containing your training data (`--dataset.repo_id=YOUR_USERNAME/YOUR_DATASET`)
# - Optional: A [wandb](https://wandb.ai/) account if you want to enable training visualization
# - Recommended: GPU runtime (e.g., NVIDIA A100) for faster training
#
# ## ⏱️ Expected Training Time
# Training with the `SmolVLA` policy for 20,000 steps typically takes **about 5 hours on an NVIDIA A100** GPU. On less powerful GPUs or CPUs, training may take significantly longer!
#
# ## Example Output
# Model checkpoints, logs, and training plots will be saved to the specified `--output_dir`. If `wandb` is enabled, progress will also be visualized in your wandb project dashboard.

# %% [markdown]
# ## Install conda
# This cell uses `condacolab` to bootstrap a full Conda environment inside Google Colab.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# ## Install LeRobot
# This cell clones the `lerobot` repository from Hugging Face, installs FFmpeg (version 7.1.1), and installs the package in editable mode.

# %%
# !git clone https://github.com/huggingface/lerobot.git
# !conda install ffmpeg=7.1.1 -c conda-forge
# !cd lerobot && pip install -e .
# Out:
# Cloning into 'lerobot'...
# remote: Enumerating objects: 41183, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 41183 (delta 37), reused 19 (delta 19), pack-reused 41127 (from 3)
# Receiving objects: 100% (41183/41183), 201.70 MiB | 32.99 MiB/s, done.
# Resolving deltas: 100% (26835/26835), done.
# Filtering content: 100% (45/45), 69.03 MiB | 51.79 MiB/s, done.
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - ffmpeg=7.1.1
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.14            |       hb9d3cd8_0         553 KB  conda-forge
#     aom-3.9.1                  |       hac33072_0         2.6 MB  conda-forge
#     attr-2.5.2                 |       h39aace5_0          66 KB  conda-forge
#     ca-certificates-2025.10.5  |       hbd8a1cb_0         152 KB  conda-forge
#     cairo-1.18.4               |       h3394656_0         955 KB  conda-forge
#     certifi-2025.10.5          |     pyhd8ed1ab_0         156 KB  conda-forge
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     dav1d-1.2.1                |       hd590300_0         742 KB  conda-forge
#     dbus-1.16.2                |       h3c4dab8_0         428 KB  conda-forge
#     ffmpeg-7.1.1               | gpl_h5c0ada0_711        10.1 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h7e30c49_1         259 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freetype-2.14.1            |       ha770c72_0         169 KB  conda-forge
#     fribidi-1.0.16             |       hb03c661_0          60 KB  conda-forge
#     gdk-pixbuf-2.44.4          |       h2b0a6b4_0         559 KB  conda-forge
#     gettext-0.25.1             |       h3f43e3d_1         529 KB  conda-forge
#     gettext-tools-0.25.1       |       h3f43e3d_1         3.5 MB  conda-forge
#     gmp-6.3.0                  |       hac33072_2         449 KB  conda-forge
#     graphite2-1.3.14           |       hecca717_2          97 KB  conda-forge
#     harfbuzz-12.1.0            |       h15599e2_0         2.0 MB  conda-forge
#     icu-75.1                   |       he02047a_0        11.6 MB  conda-forge
#     intel-gmmlib-22.8.2        |       hb700be7_0         976 KB  conda-forge
#     intel-media-driver-25.3.4  |       hecca717_0         8.0 MB  conda-forge
#     lame-3.100                 |    h166bdaf_1003         496 KB  conda-forge
#     lerc-4.0.0                 |       h0aef613_1         258 KB  conda-forge
#     level-zero-1.26.0          |       hb700be7_0         624 KB  conda-forge
#     libabseil-20250512.1       | cxx17_hba17884_0         1.2 MB  conda-forge
#     libasprintf-0.25.1         |       h3f43e3d_1          52 KB  conda-forge
#     libasprintf-devel-0.25.1   |       h3f43e3d_1          34 KB  conda-forge
#     libass-0.17.4              |       h96ad9f0_0         149 KB  conda-forge
#     libcap-2.76                |       h0b2e76d_0         119 KB  conda-forge
#     libdeflate-1.25            |       h17f619e_0          72 KB  conda-forge
#     libdrm-2.4.125             |       hb03c661_1         304 KB  conda-forge
#     libegl-1.7.0               |       ha4b6fd6_2          44 KB  conda-forge
#     libexpat-2.7.1             |       hecca717_0          73 KB  conda-forge
#     libffi-3.5.2               |       h9ec8514_0          56 KB  conda-forge
#     libflac-1.4.3              |       h59595ed_0         385 KB  conda-forge
#     libfreetype-2.14.1         |       ha770c72_0           7 KB  conda-forge
#     libfreetype6-2.14.1        |       h73754d4_0         378 KB  conda-forge
#     libgcrypt-lib-1.11.1       |       hb9d3cd8_0         577 KB  conda-forge
#     libgettextpo-0.25.1        |       h3f43e3d_1         184 KB  conda-forge
#     libgettextpo-devel-0.25.1  |       h3f43e3d_1          37 KB  conda-forge
#     libgl-1.7.0                |       ha4b6fd6_2         132 KB  conda-forge
#     libglib-2.86.1             |       h32235b2_1         3.8 MB  conda-forge
#     libglvnd-1.7.0             |       ha4b6fd6_2         129 KB  conda-forge
#     libglx-1.7.0               |       ha4b6fd6_2          74 KB  conda-forge
#     libgpg-error-1.55          |       h3f2d84a_0         305 KB  conda-forge
#     libhwloc-2.12.1            |default_h7f8ec31_1002         2.3 MB  conda-forge
#     libiconv-1.18              |       h3b78370_2         772 KB  conda-forge
#     libjpeg-turbo-3.1.2        |       hb03c661_0         619 KB  conda-forge
#     liblzma-5.8.1              |       hb9d3cd8_2         110 KB  conda-forge
#     libogg-1.3.5               |       hd0c01bc_1         213 KB  conda-forge
#     libopenvino-2025.2.0       |       hb617929_1         6.0 MB  conda-forge
#     libopenvino-auto-batch-plugin-2025.2.0|       hed573e4_1         112 KB  conda-forge
#     libopenvino-auto-plugin-2025.2.0|       hed573e4_1         245 KB  conda-forge
#     libopenvino-hetero-plugin-2025.2.0|       hd41364c_1         190 KB  conda-forge
#     libopenvino-intel-cpu-plugin-2025.2.0|       hb617929_1        11.8 MB  conda-forge
#     libopenvino-intel-gpu-plugin-2025.2.0|       hb617929_1        10.3 MB  conda-forge
#     libopenvino-intel-npu-plugin-2025.2.0|       hb617929_1         1.2 MB  conda-forge
#     libopenvino-ir-frontend-2025.2.0|       hd41364c_1         200 KB  conda-forge
#     libopenvino-onnx-frontend-2025.2.0|       h1862bb8_1         1.6 MB  conda-forge
#     libopenvino-paddle-frontend-2025.2.0|       h1862bb8_1         727 KB  conda-forge
#     libopenvino-pytorch-frontend-2025.2.0|       hecca717_1         1.2 MB  conda-forge
#     libopenvino-tensorflow-frontend-2025.2.0|       h0767aad_1         1.3 MB  conda-forge
#     libopenvino-tensorflow-lite-frontend-2025.2.0|       hecca717_1         485 KB  conda-forge
#     libopus-1.5.2              |       hd0c01bc_0         305 KB  conda-forge
#     libpciaccess-0.18          |       hb9d3cd8_0          28 KB  conda-forge
#     libpng-1.6.50              |       h421ea60_1         310 KB  conda-forge
#     libprotobuf-6.31.1         |       h49aed37_2         4.4 MB  conda-forge
#     librsvg-2.60.0             |       h61e6d4b_0         3.3 MB  conda-forge
#     libsndfile-1.2.2           |       hc60ed4a_1         346 KB  conda-forge
#     libsystemd0-257.9          |       h996ca69_0         481 KB  conda-forge
#     libtiff-4.7.1              |       h9d88235_1         425 KB  conda-forge
#     libudev1-257.9             |       h085a93f_0         141 KB  conda-forge
#     libunwind-1.8.3            |       h65a8314_0          74 KB  conda-forge
#     liburing-2.12              |       hb700be7_0         125 KB  conda-forge
#     libusb-1.0.29              |       h73b1eb8_0          87 KB  conda-forge
#     libva-2.22.0               |       h4f16b4b_2         212 KB  conda-forge
#     libvorbis-1.3.7            |       h54a6638_2         279 KB  conda-forge
#     libvpl-2.15.0              |       h54a6638_1         281 KB  conda-forge
#     libvpx-1.14.1              |       hac33072_0         999 KB  conda-forge
#     libvulkan-loader-1.4.328.1 |       h5279c79_0         193 KB  conda-forge
#     libwebp-base-1.6.0         |       hd42ef1d_0         419 KB  conda-forge
#     libxcb-1.17.0              |       h8a09558_0         387 KB  conda-forge
#     libxkbcommon-1.12.3        |       hca5e8e5_0         809 KB  conda-forge
#     libxml2-2.15.1             |       h26afc86_0          44 KB  conda-forge
#     libxml2-16-2.15.1          |       ha9997c6_0         543 KB  conda-forge
#     mpg123-1.32.9              |       hc50e24c_0         480 KB  conda-forge
#     ocl-icd-2.3.3              |       hb9d3cd8_0         104 KB  conda-forge
#     opencl-headers-2025.06.13  |       h5888daf_0          54 KB  conda-forge
#     openh264-2.6.0             |       hc22cd8d_0         714 KB  conda-forge
#     openssl-3.5.4              |       h26f9b46_0         3.0 MB  conda-forge
#     pango-1.56.4               |       hadf4263_0         445 KB  conda-forge
#     pcre2-10.46                |       h1321c63_0         1.2 MB  conda-forge
#     pixman-0.46.4              |       h54a6638_1         440 KB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     pugixml-1.15               |       h3f63f65_0         116 KB  conda-forge
#     pulseaudio-client-17.0     |       h9a8bead_2         744 KB  conda-forge
#     sdl2-2.32.56               |       h54a6638_0         575 KB  conda-forge
#     sdl3-3.2.26                |       h68140b3_0         1.8 MB  conda-forge
#     snappy-1.2.2               |       h03e3b7b_0          45 KB  conda-forge
#     svt-av1-3.1.2              |       hecca717_0         2.6 MB  conda-forge
#     tbb-2022.3.0               |       h8d10470_0         176 KB  conda-forge
#     wayland-1.24.0             |       hd6090a7_1         322 KB  conda-forge
#     wayland-protocols-1.45     |       hd8ed1ab_0         135 KB  conda-forge
#     x264-1!164.3095            |       h166bdaf_2         877 KB  conda-forge
#     x265-3.5                   |       h924138e_3         3.2 MB  conda-forge
#     xkeyboard-config-2.46      |       hb03c661_0         388 KB  conda-forge
#     xorg-libice-1.1.2          |       hb9d3cd8_0          57 KB  conda-forge
#     xorg-libsm-1.2.6           |       he73a12e_0          27 KB  conda-forge
#     xorg-libx11-1.8.12         |       h4f16b4b_0         816 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb9d3cd8_0          14 KB  conda-forge
#     xorg-libxcursor-1.2.3      |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxext-1.3.6         |       hb9d3cd8_0          49 KB  conda-forge
#     xorg-libxfixes-6.0.2       |       hb03c661_0          20 KB  conda-forge
#     xorg-libxrandr-1.5.4       |       hb9d3cd8_0          29 KB  conda-forge
#     xorg-libxrender-0.9.12     |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxscrnsaver-1.2.4   |       hb9d3cd8_0          14 KB  conda-forge
#     zstandard-0.25.0           |  py311haee01d2_0         456 KB  conda-forge
#     zstd-1.5.7                 |       hb8e6e7a_2         554 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       129.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.14-hb9d3cd8_0
#   aom                conda-forge/linux-64::aom-3.9.1-hac33072_0
#   attr               conda-forge/linux-64::attr-2.5.2-h39aace5_0
#   cairo              conda-forge/linux-64::cairo-1.18.4-h3394656_0
#   dav1d              conda-forge/linux-64::dav1d-1.2.1-hd590300_0
#   dbus               conda-forge/linux-64::dbus-1.16.2-h3c4dab8_0
#   ffmpeg             conda-forge/linux-64::ffmpeg-7.1.1-gpl_h5c0ada0_711
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/linux-64::fontconfig-2.15.0-h7e30c49_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freetype           conda-forge/linux-64::freetype-2.14.1-ha770c72_0
#   fribidi            conda-forge/linux-64::fribidi-1.0.16-hb03c661_0
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.44.4-h2b0a6b4_0
#   gettext            conda-forge/linux-64::gettext-0.25.1-h3f43e3d_1
#   gettext-tools      conda-forge/linux-64::gettext-tools-0.25.1-h3f43e3d_1
#   gmp                conda-forge/linux-64::gmp-6.3.0-hac33072_2
#   graphite2          conda-forge/linux-64::graphite2-1.3.14-hecca717_2
#   harfbuzz           conda-forge/linux-64::harfbuzz-12.1.0-h15599e2_0
#   icu                conda-forge/linux-64::icu-75.1-he02047a_0
#   intel-gmmlib       conda-forge/linux-64::intel-gmmlib-22.8.2-hb700be7_0
#   intel-media-driver conda-forge/linux-64::intel-media-driver-25.3.4-hecca717_0
#   lame               conda-forge/linux-64::lame-3.100-h166bdaf_1003
#   lerc               conda-forge/linux-64::lerc-4.0.0-h0aef613_1
#   level-zero         conda-forge/linux-64::level-zero-1.26.0-hb700be7_0
#   libabseil          conda-forge/linux-64::libabseil-20250512.1-cxx17_hba17884_0
#   libasprintf        conda-forge/linux-64::libasprintf-0.25.1-h3f43e3d_1
#   libasprintf-devel  conda-forge/linux-64::libasprintf-devel-0.25.1-h3f43e3d_1
#   libass             conda-forge/linux-64::libass-0.17.4-h96ad9f0_0
#   libcap             conda-forge/linux-64::libcap-2.76-h0b2e76d_0
#   libdeflate         conda-forge/linux-64::libdeflate-1.25-h17f619e_0
#   libdrm             conda-forge/linux-64::libdrm-2.4.125-hb03c661_1
#   libegl             conda-forge/linux-64::libegl-1.7.0-ha4b6fd6_2
#   libflac            conda-forge/linux-64::libflac-1.4.3-h59595ed_0
#   libfreetype        conda-forge/linux-64::libfreetype-2.14.1-ha770c72_0
#   libfreetype6       conda-forge/linux-64::libfreetype6-2.14.1-h73754d4_0
#   libgcrypt-lib      conda-forge/linux-64::libgcrypt-lib-1.11.1-hb9d3cd8_0
#   libgettextpo       conda-forge/linux-64::libgettextpo-0.25.1-h3f43e3d_1
#   libgettextpo-devel conda-forge/linux-64::libgettextpo-devel-0.25.1-h3f43e3d_1
#   libgl              conda-forge/linux-64::libgl-1.7.0-ha4b6fd6_2
#   libglib            conda-forge/linux-64::libglib-2.86.1-h32235b2_1
#   libglvnd           conda-forge/linux-64::libglvnd-1.7.0-ha4b6fd6_2
#   libglx             conda-forge/linux-64::libglx-1.7.0-ha4b6fd6_2
#   libgpg-error       conda-forge/linux-64::libgpg-error-1.55-h3f2d84a_0
#   libhwloc           conda-forge/linux-64::libhwloc-2.12.1-default_h7f8ec31_1002
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.1.2-hb03c661_0
#   libogg             conda-forge/linux-64::libogg-1.3.5-hd0c01bc_1
#   libopenvino        conda-forge/linux-64::libopenvino-2025.2.0-hb617929_1
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-batch-plugin-2025.2.0-hed573e4_1
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-plugin-2025.2.0-hed573e4_1
#   libopenvino-heter~ conda-forge/linux-64::libopenvino-hetero-plugin-2025.2.0-hd41364c_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-cpu-plugin-2025.2.0-hb617929_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-gpu-plugin-2025.2.0-hb617929_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-npu-plugin-2025.2.0-hb617929_1
#   libopenvino-ir-fr~ conda-forge/linux-64::libopenvino-ir-frontend-2025.2.0-hd41364c_1
#   libopenvino-onnx-~ conda-forge/linux-64::libopenvino-onnx-frontend-2025.2.0-h1862bb8_1
#   libopenvino-paddl~ conda-forge/linux-64::libopenvino-paddle-frontend-2025.2.0-h1862bb8_1
#   libopenvino-pytor~ conda-forge/linux-64::libopenvino-pytorch-frontend-2025.2.0-hecca717_1
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-frontend-2025.2.0-h0767aad_1
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-lite-frontend-2025.2.0-hecca717_1
#   libopus            conda-forge/linux-64::libopus-1.5.2-hd0c01bc_0
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.18-hb9d3cd8_0
#   libpng             conda-forge/linux-64::libpng-1.6.50-h421ea60_1
#   libprotobuf        conda-forge/linux-64::libprotobuf-6.31.1-h49aed37_2
#   librsvg            conda-forge/linux-64::librsvg-2.60.0-h61e6d4b_0
#   libsndfile         conda-forge/linux-64::libsndfile-1.2.2-hc60ed4a_1
#   libsystemd0        conda-forge/linux-64::libsystemd0-257.9-h996ca69_0
#   libtiff            conda-forge/linux-64::libtiff-4.7.1-h9d88235_1
#   libudev1           conda-forge/linux-64::libudev1-257.9-h085a93f_0
#   libunwind          conda-forge/linux-64::libunwind-1.8.3-h65a8314_0
#   liburing           conda-forge/linux-64::liburing-2.12-hb700be7_0
#   libusb             conda-forge/linux-64::libusb-1.0.29-h73b1eb8_0
#   libva              conda-forge/linux-64::libva-2.22.0-h4f16b4b_2
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h54a6638_2
#   libvpl             conda-forge/linux-64::libvpl-2.15.0-h54a6638_1
#   libvpx             conda-forge/linux-64::libvpx-1.14.1-hac33072_0
#   libvulkan-loader   conda-forge/linux-64::libvulkan-loader-1.4.328.1-h5279c79_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.6.0-hd42ef1d_0
#   libxcb             conda-forge/linux-64::libxcb-1.17.0-h8a09558_0
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.12.3-hca5e8e5_0
#   libxml2-16         conda-forge/linux-64::libxml2-16-2.15.1-ha9997c6_0
#   mpg123             conda-forge/linux-64::mpg123-1.32.9-hc50e24c_0
#   ocl-icd            conda-forge/linux-64::ocl-icd-2.3.3-hb9d3cd8_0
#   opencl-headers     conda-forge/linux-64::opencl-headers-2025.06.13-h5888daf_0
#   openh264           conda-forge/linux-64::openh264-2.6.0-hc22cd8d_0
#   pango              conda-forge/linux-64::pango-1.56.4-hadf4263_0
#   pcre2              conda-forge/linux-64::pcre2-10.46-h1321c63_0
#   pixman             conda-forge/linux-64::pixman-0.46.4-h54a6638_1
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   pugixml            conda-forge/linux-64::pugixml-1.15-h3f63f65_0
#   pulseaudio-client  conda-forge/linux-64::pulseaudio-client-17.0-h9a8bead_2
#   sdl2               conda-forge/linux-64::sdl2-2.32.56-h54a6638_0
#   sdl3               conda-forge/linux-64::sdl3-3.2.26-h68140b3_0
#   snappy             conda-forge/linux-64::snappy-1.2.2-h03e3b7b_0
#   svt-av1            conda-forge/linux-64::svt-av1-3.1.2-hecca717_0
#   tbb                conda-forge/linux-64::tbb-2022.3.0-h8d10470_0
#   wayland            conda-forge/linux-64::wayland-1.24.0-hd6090a7_1
#   wayland-protocols  conda-forge/noarch::wayland-protocols-1.45-hd8ed1ab_0
#   x264               conda-forge/linux-64::x264-1!164.3095-h166bdaf_2
#   x265               conda-forge/linux-64::x265-3.5-h924138e_3
#   xkeyboard-config   conda-forge/linux-64::xkeyboard-config-2.46-hb03c661_0
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.2-hb9d3cd8_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.6-he73a12e_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.12-h4f16b4b_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb9d3cd8_0
#   xorg-libxcursor    conda-forge/linux-64::xorg-libxcursor-1.2.3-hb9d3cd8_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb9d3cd8_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.6-hb9d3cd8_0
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-6.0.2-hb03c661_0
#   xorg-libxrandr     conda-forge/linux-64::xorg-libxrandr-1.5.4-hb9d3cd8_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.12-hb9d3cd8_0
#   xorg-libxscrnsaver conda-forge/linux-64::xorg-libxscrnsaver-1.2.4-hb9d3cd8_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/linux-64::ca-certificates~ --> conda-forge/noarch::ca-certificates-2025.10.5-hbd8a1cb_0
#   certifi                           2024.12.14-pyhd8ed1ab_0 --> 2025.10.5-pyhd8ed1ab_0
#   conda                             24.11.2-py311h38be061_1 --> 24.11.3-py311h38be061_0
#   libexpat                                 2.6.4-h5888daf_0 --> 2.7.1-hecca717_0
#   libffi                                   3.4.2-h7f98852_5 --> 3.5.2-h9ec8514_0
#   libiconv                                  1.17-hd590300_2 --> 1.18-h3b78370_2
#   liblzma                                  5.6.3-hb9d3cd8_1 --> 5.8.1-hb9d3cd8_2
#   libxml2                                 2.13.5-h0d44e9d_1 --> 2.15.1-h26afc86_0
#   openssl                                  3.4.0-h7b32b05_1 --> 3.5.4-h26f9b46_0
#   zstandard                          0.23.0-py311hbc35293_1 --> 0.25.0-py311haee01d2_0
#   zstd                                     1.5.6-ha6fb4c9_0 --> 1.5.7-hb8e6e7a_2
#
#
#
# Downloading and Extracting Packages:
# libopenvino-intel-cp | 11.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# icu-75.1             | 11.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# libopenvino-intel-gp | 10.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# ffmpeg-7.1.1         | 10.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# intel-media-driver-2 | 8.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libprotobuf-6.31.1   | 4.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libglib-2.86.1       | 3.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# librsvg-2.60.0       | 3.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-12.1.0      | 2.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.26          | 1.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libopenvino-intel-cp | 11.8 MB   | :   1% 0.00529477386687832/1 [00:00<00:19, 19.53s/it]
#
#
#
# intel-media-driver-2 | 8.0 MB    | :   2% 0.015558227621219261/1 [00:00<00:06,  6.43s/it]
#
#
# ffmpeg-7.1.1         | 10.1 MB   | :   1% 0.013986315120625993/1 [00:00<00:07,  7.53s/it]
#
# libopenvino-intel-gp | 10.3 MB   | :   0% 0.0015148657294914325/1 [00:00<01:32, 92.80s/it]
# libopenvino-intel-cp | 11.8 MB   | :  28% 0.28062301494455094/1 [00:00<00:00,  1.62it/s]
#
#
#
# intel-media-driver-2 | 8.0 MB    | :  67% 0.6651142308071234/1 [00:00<00:00,  3.87it/s]
#
#
# ffmpeg-7.1.1         | 10.1 MB   | :  39% 0.3947248934043336/1 [00:00<00:00,  2.24it/s]
#
# libopenvino-intel-gp | 10.3 MB   | :  33% 0.32721099757014943/1 [00:00<00:00,  1.64it/s]
# libopenvino-intel-cp | 11.8 MB   | :  55% 0.5480090952219061/1 [00:00<00:00,  2.09it/s]
#
#
# ffmpeg-7.1.1         | 10.1 MB   | :  80% 0.7972199618756816/1 [00:00<00:00,  3.03it/s]
#
# libopenvino-intel-gp | 10.3 MB   | :  76% 0.7604625962046991/1 [00:00<00:00,  2.76it/s]
#
#
#
# intel-media-driver-2 | 8.0 MB    | : 100% 1.0/1 [00:00<00:00,  3.87it/s]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | :   0% 0.0026236350380182075/1 [00:00<02:50, 171.43s/it]
#
#
# ffmpeg-7.1.1         | 10.1 MB   | : 100% 1.0/1 [00:00<00:00,  3.03it/s]
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:00<00:00,  1.88it/s]
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:00<00:00,  1.88it/s]
#
#
#
#
#
# libprotobuf-6.31.1   | 4.4 MB    | :   0% 0.003526568509361851/1 [00:00<02:27, 148.27s/it]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | :  45% 0.4486415915011135/1 [00:00<00:00,  1.08it/s]
#
# libopenvino-intel-gp | 10.3 MB   | : 100% 1.0/1 [00:00<00:00,  2.76it/s]
#
#
#
#
#
#
# libopenvino-intel-cp | 11.8 MB   | : 100% 1.0/1 [00:00<00:00,  1.69it/s]
#
#
#
#
#
# libprotobuf-6.31.1   | 4.4 MB    | :  71% 0.7053137018723703/1 [00:00<00:00,  1.51it/s]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | :  83% 0.8290686720137536/1 [00:00<00:00,  1.77it/s]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | :   0% 0.00449603098485416/1 [00:00<02:23, 144.55s/it]
#
#
#
#
#
#
#
#
# librsvg-2.60.0       | 3.3 MB    | :   0% 0.004787875546796486/1 [00:00<02:14, 135.58s/it]
#
#
#
#
#
#
# libglib-2.86.1       | 3.8 MB    | :  98% 0.9799062928924923/1 [00:00<00:00,  1.97it/s]
#
#
#
#
#
# libprotobuf-6.31.1   | 4.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.51it/s]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | :  83% 0.8317657321980196/1 [00:00<00:00,  1.49it/s]
#
#
#
#
#
#
# libglib-2.86.1       | 3.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.97it/s]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.77it/s]
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | :   0% 0.004880274801411181/1 [00:00<02:42, 163.65s/it]
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 3.0 MB    | :   1% 0.005251914974368706/1 [00:00<02:33, 154.27s/it]
#
#
#
#
#
#
#
#
# librsvg-2.60.0       | 3.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.58it/s]
#
#
#
#
#
#
#
#
# librsvg-2.60.0       | 3.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.58it/s]
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | :   1% 0.005976944403910696/1 [00:00<02:19, 140.77s/it]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.49it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | :   1% 0.006053807351178468/1 [00:00<02:30, 150.94s/it]
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.44it/s]
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.44it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | :   1% 0.006685595039993602/1 [00:00<02:20, 141.43s/it]
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.38it/s]
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.38it/s]
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.35it/s]
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.26          | 1.8 MB    | :   1% 0.008461446295844884/1 [00:01<02:01, 122.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-12.1.0      | 2.0 MB    | :   1% 0.007959526120595759/1 [00:01<02:10, 131.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | :   1% 0.00950070832002032/1 [00:01<01:53, 114.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | :   1% 0.010110434778315882/1 [00:01<01:51, 112.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.26          | 1.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.19it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.26          | 1.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.19it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | : 100% 1.0/1 [00:01<00:00, 114.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-12.1.0      | 2.0 MB    | : 100% 1.0/1 [00:01<00:00,  1.17it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-12.1.0      | 2.0 MB    | : 100% 1.0/1 [00:01<00:00,  1.17it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:01<00:00, 112.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# intel-media-driver-2 | 8.0 MB    | : 100% 1.0/1 [00:01<00:00,  3.87it/s]
#
#
# ffmpeg-7.1.1         | 10.1 MB   | : 100% 1.0/1 [00:01<00:00,  3.03it/s]
#
# libopenvino-intel-gp | 10.3 MB   | : 100% 1.0/1 [00:02<00:00,  2.76it/s]
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:02<00:00,  1.88it/s]
#
#
#
#
#
# libopenvino-intel-cp | 11.8 MB   | : 100% 1.0/1 [00:03<00:00,  1.69it/s]
#
#
#
#
#
#
# libglib-2.86.1       | 3.8 MB    | : 100% 1.0/1 [00:03<00:00,  1.97it/s]
#
#
#
#
# libopenvino-2025.2.0 | 6.0 MB    | : 100% 1.0/1 [00:03<00:00,  1.77it/s]
#
#
#
#
#
#
#
#
# librsvg-2.60.0       | 3.3 MB    | : 100% 1.0/1 [00:03<00:00,  1.58it/s]
#
#
#
#
#
#
#
# gettext-tools-0.25.1 | 3.5 MB    | : 100% 1.0/1 [00:03<00:00,  1.49it/s]
#
#
#
#
#
#
#
#
#
#
# openssl-3.5.4        | 3.0 MB    | : 100% 1.0/1 [00:03<00:00,  1.38it/s]
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-3.1.2        | 2.6 MB    | : 100% 1.0/1 [00:04<00:00,  1.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | : 100% 1.0/1 [00:04<00:00,  1.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libhwloc-2.12.1      | 2.3 MB    | : 100% 1.0/1 [00:04<00:00,  1.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | : 100% 1.0/1 [00:04<00:00,  4.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.6 MB    | : 100% 1.0/1 [00:04<00:00,  4.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sdl3-3.2.26          | 1.8 MB    | : 100% 1.0/1 [00:04<00:00,  1.19it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-12.1.0      | 2.0 MB    | : 100% 1.0/1 [00:04<00:00,  1.17it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:04<00:00,  4.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:04<00:00,  4.24s/it]
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | : 100% 1.0/1 [00:04<00:00,  1.44it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# |
# |
# done
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting datasets<4.2.0,>=4.0.0 (from lerobot==0.4.1)
#   Downloading datasets-4.1.1-py3-none-any.whl.metadata (18 kB)
# Collecting diffusers<0.36.0,>=0.27.2 (from lerobot==0.4.1)
#   Downloading diffusers-0.35.2-py3-none-any.whl.metadata (20 kB)
# Collecting huggingface-hub<0.36.0,>=0.34.2 (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1)
#   Downloading huggingface_hub-0.35.3-py3-none-any.whl.metadata (14 kB)
# Collecting accelerate<2.0.0,>=1.10.0 (from lerobot==0.4.1)
#   Downloading accelerate-1.11.0-py3-none-any.whl.metadata (19 kB)
# Collecting setuptools<81.0.0,>=71.0.0 (from lerobot==0.4.1)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting cmake<4.2.0,>=3.29.0.1 (from lerobot==0.4.1)
#   Downloading cmake-4.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.5 kB)
# Collecting einops<0.9.0,>=0.8.0 (from lerobot==0.4.1)
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting opencv-python-headless<4.13.0,>=4.9.0 (from lerobot==0.4.1)
#   Downloading opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting av<16.0.0,>=15.0.0 (from lerobot==0.4.1)
#   Downloading av-15.1.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting jsonlines<5.0.0,>=4.0.0 (from lerobot==0.4.1)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging<26.0,>=24.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (24.2)
# Collecting pynput<1.9.0,>=1.7.7 (from lerobot==0.4.1)
#   Downloading pynput-1.8.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting pyserial<4.0,>=3.5 (from lerobot==0.4.1)
#   Downloading pyserial-3.5-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting wandb<0.22.0,>=0.20.0 (from lerobot==0.4.1)
#   Downloading wandb-0.21.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting torch<2.8.0,>=2.2.1 (from lerobot==0.4.1)
#   Downloading torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchcodec<0.6.0,>=0.2.1 (from lerobot==0.4.1)
#   Downloading torchcodec-0.5-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting torchvision<0.23.0,>=0.21.0 (from lerobot==0.4.1)
#   Downloading torchvision-0.22.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting draccus==0.10.0 (from lerobot==0.4.1)
#   Downloading draccus-0.10.0-py3-none-any.whl.metadata (24 kB)
# Collecting gymnasium<2.0.0,>=1.1.1 (from lerobot==0.4.1)
#   Downloading gymnasium-1.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting rerun-sdk<0.27.0,>=0.24.0 (from lerobot==0.4.1)
#   Downloading rerun_sdk-0.26.2-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting deepdiff<9.0.0,>=7.0.1 (from lerobot==0.4.1)
#   Downloading deepdiff-8.6.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting imageio<3.0.0,>=2.34.0 (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.1)
#   Downloading imageio-2.37.2-py3-none-any.whl.metadata (9.7 kB)
# Collecting termcolor<4.0.0,>=2.4.0 (from lerobot==0.4.1)
#   Downloading termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting mergedeep~=1.3 (from draccus==0.10.0->lerobot==0.4.1)
#   Downloading mergedeep-1.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyyaml~=6.0 (from draccus==0.10.0->lerobot==0.4.1)
#   Downloading pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting pyyaml-include~=1.4 (from draccus==0.10.0->lerobot==0.4.1)
#   Downloading pyyaml_include-1.4.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting toml~=0.10 (from draccus==0.10.0->lerobot==0.4.1)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect~=0.9.0 (from draccus==0.10.0->lerobot==0.4.1)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting numpy>=1.17 (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1)
#   Downloading numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting psutil (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1)
#   Downloading psutil-7.1.3-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (23 kB)
# Collecting safetensors>=0.4.3 (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1)
#   Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting filelock (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting pyarrow>=21.0.0 (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading pyarrow-22.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (4.67.1)
# Collecting xxhash (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading xxhash-3.6.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.9.0,>=2023.1.0 (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting orderly-set<6,>=5.4.1 (from deepdiff<9.0.0,>=7.0.1->lerobot==0.4.1)
#   Downloading orderly_set-5.5.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting importlib_metadata (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting regex!=2019.12.17 (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1)
#   Downloading regex-2025.11.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting Pillow (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1)
#   Downloading pillow-12.0.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions>=4.3.0 (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting farama-notifications>=0.0.1 (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<0.36.0,>=0.34.2->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1)
#   Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting InquirerPy==0.3.4 (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1)
#   Downloading InquirerPy-0.3.4-py3-none-any.whl.metadata (8.1 kB)
# Collecting hf-transfer>=0.1.4 (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1)
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting pfzy<0.4.0,>=0.3.1 (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1)
#   Downloading pfzy-0.3.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting prompt-toolkit<4.0.0,>=3.0.1 (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1)
#   Downloading prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Collecting imageio-ffmpeg (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.1)
#   Downloading imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting attrs>=19.2.0 (from jsonlines<5.0.0,>=4.0.0->lerobot==0.4.1)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting numpy>=1.17 (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1)
#   Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting six (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting evdev>=1.3 (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1)
#   Downloading evdev-1.9.2.tar.gz (33 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting python-xlib>=0.17 (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1)
#   Downloading python_xlib-0.33-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting sympy>=1.13.3 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Collecting click>=8.0.1 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (4.3.6)
# Collecting protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting pydantic<3 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading pydantic-2.12.3-py3-none-any.whl.metadata (87 kB)
# Collecting sentry-sdk>=2.0.0 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading sentry_sdk-2.43.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading aiohttp-3.13.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.4 (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading pydantic_core-2.41.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.10.5)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.4.1)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting zipp>=3.20 (from importlib_metadata->diffusers<0.36.0,>=0.27.2->lerobot==0.4.1)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch<2.8.0,>=2.2.1->lerobot==0.4.1)
#   Downloading markupsafe-3.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Collecting python-dateutil>=2.8.2 (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading frozenlist-1.8.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading multidict-6.7.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading propcache-0.4.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1)
#   Downloading yarl-1.22.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (75 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.1)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting wcwidth (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1)
#   Downloading wcwidth-0.2.14-py2.py3-none-any.whl.metadata (15 kB)
# Downloading draccus-0.10.0-py3-none-any.whl (71 kB)
# Downloading accelerate-1.11.0-py3-none-any.whl (375 kB)
# Downloading av-15.1.0-cp311-cp311-manylinux_2_28_x86_64.whl (39.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.6/39.6 MB 89.9 MB/s eta 0:00:00
# Downloading cmake-4.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (29.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 58.8 MB/s eta 0:00:00
# Downloading datasets-4.1.1-py3-none-any.whl (503 kB)
# Downloading deepdiff-8.6.1-py3-none-any.whl (91 kB)
# Downloading diffusers-0.35.2-py3-none-any.whl (4.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 111.1 MB/s eta 0:00:00
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
# Downloading gymnasium-1.2.2-py3-none-any.whl (952 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 58.2 MB/s eta 0:00:00
# Downloading huggingface_hub-0.35.3-py3-none-any.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.3/564.3 kB 27.0 MB/s eta 0:00:00
# Downloading InquirerPy-0.3.4-py3-none-any.whl (67 kB)
# Downloading imageio-2.37.2-py3-none-any.whl (317 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (54.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 MB 61.0 MB/s eta 0:00:00
# Downloading pynput-1.8.1-py2.py3-none-any.whl (91 kB)
# Downloading pyserial-3.5-py2.py3-none-any.whl (90 kB)
# Downloading rerun_sdk-0.26.2-cp39-abi3-manylinux_2_28_x86_64.whl (98.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.8/98.8 MB 56.4 MB/s eta 0:00:00
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Downloading termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Downloading torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (821.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 21.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 38.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 112.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 125.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 52.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 49.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 66.0 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 43.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 49.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 59.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 65.5 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 61.9 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 52.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 55.2 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 56.4 MB/s eta 0:00:00
# Downloading torchcodec-0.5-cp311-cp311-manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 41.8 MB/s eta 0:00:00
# Downloading torchvision-0.22.1-cp311-cp311-manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 79.6 MB/s eta 0:00:00
# Downloading wandb-0.21.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.6/19.6 MB 90.7 MB/s eta 0:00:00
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading click-8.3.0-py3-none-any.whl (107 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 78.3 MB/s eta 0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 70.4 MB/s eta 0:00:00
# Downloading mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
# Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 93.2 MB/s eta 0:00:00
# Downloading orderly_set-5.5.0-py3-none-any.whl (13 kB)
# Downloading pillow-12.0.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 88.7 MB/s eta 0:00:00
# Downloading protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Downloading pyarrow-22.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (47.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 42.2 MB/s eta 0:00:00
# Downloading pydantic-2.12.3-py3-none-any.whl (462 kB)
# Downloading pydantic_core-2.41.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 64.4 MB/s eta 0:00:00
# Downloading python_xlib-0.33-py2.py3-none-any.whl (182 kB)
# Downloading pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (806 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.6/806.6 kB 46.0 MB/s eta 0:00:00
# Downloading pyyaml_include-1.4.1-py3-none-any.whl (19 kB)
# Downloading regex-2025.11.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (800 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.4/800.4 kB 44.3 MB/s eta 0:00:00
# Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (485 kB)
# Downloading sentry_sdk-2.43.0-py2.py3-none-any.whl (400 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 86.8 MB/s eta 0:00:00
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Downloading imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl (29.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 93.2 MB/s eta 0:00:00
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 69.2 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 96.7 MB/s eta 0:00:00
# Downloading psutil-7.1.3-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (263 kB)
# Downloading xxhash-3.6.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Downloading aiohttp-3.13.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 66.7 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading markupsafe-3.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 28.0 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pfzy-0.3.4-py3-none-any.whl (8.5 kB)
# Downloading prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (231 kB)
# Downloading multidict-6.7.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (246 kB)
# Downloading propcache-0.4.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (210 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading yarl-1.22.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (365 kB)
# Downloading wcwidth-0.2.14-py2.py3-none-any.whl (37 kB)
# Building wheels for collected packages: lerobot, evdev
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.4.1-0.editable-py3-none-any.whl size=15638 sha256=0d021cbc3259df32cf58cebbcb12d285e6d143903409eb2bffc8f19095e972d4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rjjhos1g/wheels/15/0d/02/b9c6ff1c78574dee99101ad231194b3425eb4cd784ce8c8338
#   Building wheel for evdev (pyproject.toml) ... done
#   Created wheel for evdev: filename=evdev-1.9.2-cp311-cp311-linux_x86_64.whl size=74951 sha256=71417e927c684d549eebca5ae17f2c38326690ef44efbf3562226931b1246198
#   Stored in directory: /root/.cache/pip/wheels/72/97/d0/ea1b02915719d1cdb6a8810aa7683524c7aceedc5812cdeed7
# Successfully built lerobot evdev
# Installing collected packages: pytz, pyserial, nvidia-cusparselt-cu12, mpmath, farama-notifications, zipp, xxhash, wcwidth, tzdata, typing-extensions, torchcodec, toml, termcolor, sympy, smmap, six, setuptools, sentry-sdk, safetensors, regex, pyyaml, pyarrow, psutil, protobuf, propcache, Pillow, pfzy, orderly-set, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, mypy-extensions, multidict, mergedeep, MarkupSafe, imageio-ffmpeg, hf-xet, hf-transfer, fsspec, frozenlist, filelock, evdev, einops, dill, cmake, cloudpickle, click, av, attrs, annotated-types, aiohappyeyeballs, yarl, typing-inspection, typing-inspect, triton, rerun-sdk, pyyaml-include, python-xlib, python-dateutil, pydantic-core, prompt-toolkit, opencv-python-headless, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, multiprocess, jsonlines, jinja2, importlib_metadata, imageio, huggingface-hub, gymnasium, gitdb, deepdiff, aiosignal, pynput, pydantic, pandas, nvidia-cusolver-cu12, InquirerPy, gitpython, draccus, diffusers, aiohttp, wandb, torch, torchvision, datasets, accelerate, lerobot
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.6.3
#     Uninstalling setuptools-65.6.3:
#       Successfully uninstalled setuptools-65.6.3
# Successfully installed InquirerPy-0.3.4 MarkupSafe-3.0.3 Pillow-12.0.0 accelerate-1.11.0 aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiosignal-1.4.0 annotated-types-0.7.0 attrs-25.4.0 av-15.1.0 click-8.3.0 cloudpickle-3.1.2 cmake-4.1.2 datasets-4.1.1 deepdiff-8.6.1 diffusers-0.35.2 dill-0.4.0 draccus-0.10.0 einops-0.8.1 evdev-1.9.2 farama-notifications-0.0.4 filelock-3.20.0 frozenlist-1.8.0 fsspec-2025.9.0 gitdb-4.0.12 gitpython-3.1.45 gymnasium-1.2.2 hf-transfer-0.1.9 hf-xet-1.2.0 huggingface-hub-0.35.3 imageio-2.37.2 imageio-ffmpeg-0.6.0 importlib_metadata-8.7.0 jinja2-3.1.6 jsonlines-4.0.0 lerobot-0.4.1 mergedeep-1.3.4 mpmath-1.3.0 multidict-6.7.0 multiprocess-0.70.16 mypy-extensions-1.1.0 networkx-3.5 numpy-2.2.6 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 opencv-python-headless-4.12.0.88 orderly-set-5.5.0 pandas-2.3.3 pfzy-0.3.4 prompt-toolkit-3.0.52 propcache-0.4.1 protobuf-6.33.0 psutil-7.1.3 pyarrow-22.0.0 pydantic-2.12.3 pydantic-core-2.41.4 pynput-1.8.1 pyserial-3.5 python-dateutil-2.9.0.post0 python-xlib-0.33 pytz-2025.2 pyyaml-6.0.3 pyyaml-include-1.4.1 regex-2025.11.3 rerun-sdk-0.26.2 safetensors-0.6.2 sentry-sdk-2.43.0 setuptools-80.9.0 six-1.17.0 smmap-5.0.2 sympy-1.14.0 termcolor-3.2.0 toml-0.10.2 torch-2.7.1 torchcodec-0.5 torchvision-0.22.1 triton-3.3.1 typing-extensions-4.15.0 typing-inspect-0.9.0 typing-inspection-0.4.2 tzdata-2025.2 wandb-0.21.4 wcwidth-0.2.14 xxhash-3.6.0 yarl-1.22.0 zipp-3.23.0

# %% [markdown]
# ## Weights & Biases login
# This cell logs you into Weights & Biases (wandb) to enable experiment tracking and logging.

# %%
# !wandb login

# %% [markdown]
# ## Install SmolVLA dependencies

# %%
# !cd lerobot && pip install -e ".[smolvla]"
# Out:
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: datasets<4.2.0,>=4.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (4.1.1)
# Requirement already satisfied: diffusers<0.36.0,>=0.27.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.35.2)
# Requirement already satisfied: huggingface-hub<0.36.0,>=0.34.2 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.35.3)
# Requirement already satisfied: accelerate<2.0.0,>=1.10.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (1.11.0)
# Requirement already satisfied: setuptools<81.0.0,>=71.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (80.9.0)
# Requirement already satisfied: cmake<4.2.0,>=3.29.0.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (4.1.2)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.8.1)
# Requirement already satisfied: opencv-python-headless<4.13.0,>=4.9.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (4.12.0.88)
# Requirement already satisfied: av<16.0.0,>=15.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (15.1.0)
# Requirement already satisfied: jsonlines<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (4.0.0)
# Requirement already satisfied: packaging<26.0,>=24.2 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (24.2)
# Requirement already satisfied: pynput<1.9.0,>=1.7.7 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (1.8.1)
# Requirement already satisfied: pyserial<4.0,>=3.5 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (3.5)
# Requirement already satisfied: wandb<0.22.0,>=0.20.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.21.4)
# Requirement already satisfied: torch<2.8.0,>=2.2.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (2.7.1)
# Requirement already satisfied: torchcodec<0.6.0,>=0.2.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.5)
# Requirement already satisfied: torchvision<0.23.0,>=0.21.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.22.1)
# Requirement already satisfied: draccus==0.10.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.10.0)
# Requirement already satisfied: gymnasium<2.0.0,>=1.1.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (1.2.2)
# Requirement already satisfied: rerun-sdk<0.27.0,>=0.24.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.26.2)
# Requirement already satisfied: deepdiff<9.0.0,>=7.0.1 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (8.6.1)
# Requirement already satisfied: imageio<3.0.0,>=2.34.0 in /usr/local/lib/python3.11/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.1) (2.37.2)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (3.2.0)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (6.0.3)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.11/site-packages (from draccus==0.10.0->lerobot==0.4.1) (0.9.0)
# Collecting num2words<0.6.0,>=0.5.14 (from lerobot==0.4.1)
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: safetensors<1.0.0,>=0.4.3 in /usr/local/lib/python3.11/site-packages (from lerobot==0.4.1) (0.6.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1) (2.2.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.1) (7.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.20.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (0.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.9.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /usr/local/lib/python3.11/site-packages (from deepdiff<9.0.0,>=7.0.1->lerobot==0.4.1) (5.5.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (8.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (2025.11.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (12.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.1) (0.0.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/site-packages (from huggingface-hub<0.36.0,>=0.34.2->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (1.2.0)
# Requirement already satisfied: InquirerPy==0.3.4 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.3.4)
# Requirement already satisfied: hf-transfer>=0.1.4 in /usr/local/lib/python3.11/site-packages (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.1.9)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (3.0.52)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/site-packages (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.1) (0.6.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/site-packages (from jsonlines<5.0.0,>=4.0.0->lerobot==0.4.1) (25.4.0)
# Collecting docopt>=0.6.2 (from num2words<0.6.0,>=0.5.14->lerobot==0.4.1)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1) (1.17.0)
# Requirement already satisfied: evdev>=1.3 in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1) (1.9.2)
# Requirement already satisfied: python-xlib>=0.17 in /usr/local/lib/python3.11/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.1) (0.33)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /usr/local/lib/python3.11/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.3.1)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (6.33.0)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (2.12.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (2.43.0)
# Collecting transformers<5.0.0,>=4.53.0 (from lerobot==0.4.1)
#   Downloading transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.13.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.11/site-packages (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/site-packages (from sympy>=1.13.3->torch<2.8.0,>=2.2.1->lerobot==0.4.1) (1.3.0)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<5.0.0,>=4.53.0->lerobot==0.4.1)
#   Downloading tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/site-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.4.1) (1.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/site-packages (from importlib_metadata->diffusers<0.36.0,>=0.27.2->lerobot==0.4.1) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->torch<2.8.0,>=2.2.1->lerobot==0.4.1) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.1) (1.22.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.1) (5.0.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/site-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.1) (0.2.14)
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
# Downloading transformers-4.57.1-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 150.6 MB/s eta 0:00:00
# Downloading tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 127.4 MB/s eta 0:00:00
# Building wheels for collected packages: lerobot, docopt
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.4.1-0.editable-py3-none-any.whl size=15638 sha256=dd0276e9ea89eec650ac286e35d4e4b0fd99c20215991a7648fa25c64c295a2e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q0be42e9/wheels/15/0d/02/b9c6ff1c78574dee99101ad231194b3425eb4cd784ce8c8338
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13783 sha256=794a166d75b83af503b266fdaa52fac25a9158366cc4c82f73298311050b38a5
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built lerobot docopt
# Installing collected packages: docopt, num2words, tokenizers, transformers, lerobot
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.4.1
#     Uninstalling lerobot-0.4.1:
#       Successfully uninstalled lerobot-0.4.1
# Successfully installed docopt-0.6.2 lerobot-0.4.1 num2words-0.5.14 tokenizers-0.22.1 transformers-4.57.1

# %% [markdown]
# ## Start training SmolVLA with LeRobot
#
# This cell runs the `train.py` script from the `lerobot` library to train a robot control policy.
#
# Make sure to adjust the following arguments to your setup:
#
# 1. `--dataset.repo_id=YOUR_HF_USERNAME/YOUR_DATASET`:
#    Replace this with the Hugging Face Hub repo ID where your dataset is stored, e.g., `pepijn223/il_gym0`.
#
# 2. `--batch_size=64`: means the model processes 64 training samples in parallel before doing one gradient update. Reduce this number if you have a GPU with low memory.
#
# 3. `--output_dir=outputs/train/...`:
#    Directory where training logs and model checkpoints will be saved.
#
# 4. `--job_name=...`:
#    A name for this training job, used for logging and Weights & Biases.
#
# 5. `--policy.device=cuda`:
#    Use `cuda` if training on an NVIDIA GPU. Use `mps` for Apple Silicon, or `cpu` if no GPU is available.
#
# 6. `--wandb.enable=true`:
#    Enables Weights & Biases for visualizing training progress. You must be logged in via `wandb login` before running this.

# %%
# !cd lerobot && python src/lerobot/scripts/lerobot_train.py \
  --policy.path=allen02/smolVLA_test \
  --dataset.repo_id=lerobot/svla_so101_pickplace \
  --batch_size=4 \
  --steps=20000 \
  --output_dir=outputs/train/my_smolvla \
  --job_name=my_smolvla_training \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=allen02/smolVLA_test
# Out:
# INFO 2025-11-05 02:51:01 ot_train.py:163 {'batch_size': 4,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'lerobot/svla_so101_pickplace',
#              'revision': None,
#              'root': None,
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 20000,
#  'job_name': 'my_smolvla_training',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.95],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 0.0001,
#                'type': 'adamw',
#                'weight_decay': 1e-10},
#  'output_dir': 'outputs/train/my_smolvla',
#  'policy': {'adapt_to_pi_aloha': False,
#             'add_image_special_tokens': False,
#             'attention_mode': 'cross_attn',
#             'chunk_size': 50,
#             'device': 'cuda',
#             'empty_cameras': 0,
#             'expert_width_multiplier': 0.75,
#             'freeze_vision_encoder': True,
#             'input_features': {'observation.images.side': {'shape': [480,
#                                                                      640,
#                                                                      3],
#                                                            'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                'observation.images.up': {'shape': [480, 640, 3],
#                                                          'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                'observation.state': {'shape': [6],
#                                                      'type': <FeatureType.STATE: 'STATE'>}},
#             'license': None,
#             'load_vlm_weights': True,
#             'max_action_dim': 32,
#             'max_period': 4.0,
#             'max_state_dim': 32,
#             'min_period': 0.004,
#             'n_action_steps': 50,
#             'n_obs_steps': 1,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.IDENTITY: 'IDENTITY'>},
#             'num_expert_layers': 0,
#             'num_steps': 10,
#             'num_vlm_layers': 16,
#             'optimizer_betas': [0.9, 0.95],
#             'optimizer_eps': 1e-08,
#             'optimizer_grad_clip_norm': 10.0,
#             'optimizer_lr': 0.0001,
#             'optimizer_weight_decay': 1e-10,
#             'output_features': {'action': {'shape': [6],
#                                            'type': <FeatureType.ACTION: 'ACTION'>}},
#             'pad_language_to': 'max_length',
#             'prefix_length': 0,
#             'pretrained_path': 'allen02/smolVLA_test',
#             'private': None,
#             'push_to_hub': True,
#             'repo_id': 'allen02/smolVLA_test',
#             'resize_imgs_with_padding': [512, 512],
#             'scheduler_decay_lr': 2.5e-06,
#             'scheduler_decay_steps': 30000,
#             'scheduler_warmup_steps': 1000,
#             'self_attn_every_n_layers': 2,
#             'tags': None,
#             'tokenizer_max_length': 48,
#             'train_expert_only': True,
#             'train_state_proj': True,
#             'type': 'smolvla',
#             'use_amp': False,
#             'use_cache': True,
#             'use_delta_joint_actions_aloha': False,
#             'vlm_model_name': 'HuggingFaceTB/SmolVLM2-500M-Video-Instruct'},
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 20000,
#  'scheduler': {'decay_lr': 2.5e-06,
#                'num_decay_steps': 30000,
#                'num_warmup_steps': 1000,
#                'peak_lr': 0.0001,
#                'type': 'cosine_decay_with_warmup'},
#  'seed': 1000,
#  'steps': 20000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': False,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# INFO 2025-11-05 02:51:01 ot_train.py:171 Logs will be saved locally.
# INFO 2025-11-05 02:51:01 ot_train.py:183 Creating dataset
# INFO 2025-11-05 02:51:01 ot_train.py:202 Creating policy
# Loading  HuggingFaceTB/SmolVLM2-500M-Video-Instruct weights ...
# `torch_dtype` is deprecated! Use `dtype` instead!
# Reducing the number of VLM layers to 16 ...
# INFO 2025-11-05 02:51:23 ot_train.py:247 Creating optimizer and scheduler
# INFO 2025-11-05 02:51:23 hedulers.py:105 Auto-scaling LR scheduler: num_training_steps (20000) < num_decay_steps (30000). Scaling warmup: 1000 → 666, decay: 30000 → 20000 (scale factor: 0.667)
# INFO 2025-11-05 02:51:23 ot_train.py:259 Output dir: outputs/train/my_smolvla
# INFO 2025-11-05 02:51:23 ot_train.py:262 cfg.steps=20000 (20K)
# INFO 2025-11-05 02:51:23 ot_train.py:263 dataset.num_frames=11939 (12K)
# INFO 2025-11-05 02:51:23 ot_train.py:264 dataset.num_episodes=50
# INFO 2025-11-05 02:51:23 ot_train.py:267 Effective batch size: 4 x 1 = 4
# INFO 2025-11-05 02:51:23 ot_train.py:268 num_learnable_params=99880992 (100M)
# INFO 2025-11-05 02:51:23 ot_train.py:269 num_total_params=450046176 (450M)
# /usr/local/lib/python3.11/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# INFO 2025-11-05 02:51:23 ot_train.py:324 Start offline training on a fixed dataset
# INFO 2025-11-05 02:55:29 ot_train.py:351 step:200 smpl:800 ep:3 epch:0.07 loss:0.105 grdn:1.881 lr:1.5e-05 updt_s:1.213 data_s:0.015
# INFO 2025-11-05 02:59:34 ot_train.py:351 step:400 smpl:2K ep:7 epch:0.13 loss:0.075 grdn:1.702 lr:4.5e-05 updt_s:1.217 data_s:0.007
# INFO 2025-11-05 03:03:39 ot_train.py:351 step:600 smpl:2K ep:10 epch:0.20 loss:0.087 grdn:1.643 lr:7.5e-05 updt_s:1.216 data_s:0.006

# %% [markdown]
# ## Login into Hugging Face Hub
# Now after training is done login into the Hugging Face hub and upload the last checkpoint

# %%
# !huggingface-cli login

# %%
# !huggingface-cli upload ${HF_USER}/my_smolvla \
  /content/lerobot/outputs/train/my_smolvla/checkpoints/last/pretrained_model
